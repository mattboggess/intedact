# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import seaborn as sns
from plotnine import *
from matplotlib import gridspec
import matplotlib.pyplot as plt
from intedact import univariate_eda_interact
from intedact import continuous_univariate_summary, discrete_univariate_summary, datetime_univariate_summary
from intedact import histogram, boxplot, countplot, time_series_countplot, time_series_plot
import missingno as msno
theme_set(theme_bw())
sns.set_style("whitegrid")

# %% [markdown]
# # Load and fix data types

# %%
import numpy as np
data = pd.read_csv("https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2020-06.csv", parse_dates=True)
#data["lpep_pickup_datetime"] = pd.to_datetime(data["lpep_pickup_datetime"])
#data["lpep_dropoff_datetime"] = pd.to_datetime(data["lpep_dropoff_datetime"])
data["RatecodeID"] = data.RatecodeID.replace({
    1: "Standard Rate",
    2: "JFK",
    3: "Newark",
    4: "Nassau or Westchester",
    5: "Negotiated Fare",
    6: "Group Ride"
})
data["payment_type"] = data.payment_type.replace({
    1: "Credit Card",
    2: "Cash",
    3: "No Charge",
    4: "Dispute",
    5: "Unknown",
    6: "Voided Trip"
})
data["trip_type"] = data.trip_type.replace({
    1: "Street Hail",
    2: "Dispatch"
})
data = data.drop("ehail_fee", axis="columns")
data["id"] = np.arange(data.shape[0])

# %% [markdown]
# # Univariate EDA

# %%
univariate_eda_interact(data)
# Out:
# interactive(children=(Dropdown(description='column: Column to be plotted', options=('VendorID', 'lpep_pickup_d…

# %% [markdown]
# # Generate Markdown

# %%
from intedact import generate_config_file
config = generate_config_file(data, "./config.json")

# %%
from intedact import generate_eda_summary
generate_eda_summary(data, ".", "NYC Green Taxi Trips", "./taxi_config.json", "./taxi_data_dictionary.json");
# Out:
# /home/mattb/projects/intedact/intedact/utils.py:368: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/mattb/projects/intedact/intedact/utils.py:368: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/mattb/projects/intedact/intedact/utils.py:368: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import re
re.match(r".*memory usage", "fakjalfdaf'afafaekjlkfae memory usage").group(0)
# Out:
# "fakjalfdaf'afafaekjlkfae memory usage"

# %% [markdown]
# # Load and Clean Data

# %% [markdown]
# # Univariate EDA
